# %%
import numpy as np
import cv2
from matplotlib.pyplot import imshow

# %%
from keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Sequential

# %%
import os
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = "true"

# %%
np.random.seed(42)

SIZE=256
img_data=[]

img=cv2.imread('./mon.jpg', 1)   #Change 1 to 0 for grey images
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #Changing BGR to RGB to show images in true colors
img=cv2.resize(img,(SIZE, SIZE))
img_data.append(img_to_array(img))

img_array = np.reshape(img_data, (len(img_data), SIZE, SIZE, 3))
img_array = img_array.astype('float32') / 255.


model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(SIZE, SIZE, 3)))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
 

model.add(MaxPooling2D((2, 2), padding='same'))
     
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(3, (3, 3), activation='relu', padding='same'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
model.summary()



model.fit(img_array, img_array,
        epochs=50,
        shuffle=True)


print("Neural network output")
pred = model.predict(img_array)



imshow(pred[0].reshape(SIZE,SIZE,3), cmap="gray")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 256, 256, 32)      896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 128, 128, 8)       2312
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 64, 64, 8)         584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 32, 32, 8)         584
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 64, 64, 8)         584
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 128, 128, 32)      2336
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 256, 256, 3)       867
# =================================================================
# Total params: 8,163
# Trainable params: 8,163
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1040 - accuracy: 0.2550
# Epoch 2/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0919 - accuracy: 0.3137
# Epoch 3/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0773 - accuracy: 0.4618
# Epoch 4/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0626 - accuracy: 0.5097
# Epoch 5/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0540 - accuracy: 0.5124
# Epoch 6/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0612 - accuracy: 0.5142
# Epoch 7/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0646 - accuracy: 0.5145
# Epoch 8/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0594 - accuracy: 0.5145
# Epoch 9/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0544 - accuracy: 0.5145
# Epoch 10/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0527 - accuracy: 0.5145
# Epoch 11/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0534 - accuracy: 0.5146
# Epoch 12/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0548 - accuracy: 0.5146
# Epoch 13/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0557 - accuracy: 0.5146
# Epoch 14/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0556 - accuracy: 0.5151
# Epoch 15/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0545 - accuracy: 0.5183
# Epoch 16/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 0.5185
# Epoch 17/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0487 - accuracy: 0.5187
# Epoch 18/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 0.5190
# Epoch 19/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0358 - accuracy: 0.5185
# Epoch 20/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.5162
# Epoch 21/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 0.5164
# Epoch 22/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 0.5187
# Epoch 23/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.5041
# Epoch 24/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.4418
# Epoch 25/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0172 - accuracy: 0.2854
# Epoch 26/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0173 - accuracy: 0.2595
# Epoch 27/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 0.2474
# Epoch 28/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 0.2457
# Epoch 29/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 0.2450
# Epoch 30/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.2455
# Epoch 31/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 0.2475
# Epoch 32/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 0.2551
# Epoch 33/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0146 - accuracy: 0.2901
# Epoch 34/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 0.3273
# Epoch 35/50
# 1/1 [==============================] - 0s 998us/step - loss: 0.0135 - accuracy: 0.3974
# Epoch 36/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 0.4498
# Epoch 37/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 0.4795
# Epoch 38/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0123 - accuracy: 0.4955
# Epoch 39/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 0.5010
# Epoch 40/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 0.5025
# Epoch 41/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.5041
# Epoch 42/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 0.5089
# Epoch 43/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.5139
# Epoch 44/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.5157
# Epoch 45/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 0.5164
# Epoch 46/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 0.5168
# Epoch 47/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 0.5184
# Epoch 48/50
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 0.5213
# Epoch 49/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.5227
# Epoch 50/50
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0105 - accuracy: 0.5249
# Neural network output
